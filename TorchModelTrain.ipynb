# %% [markdown]
# # Vérification de l’appareil et utilisation de MPS

# %%
import torch

# Vérifier si MPS est disponible
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Utilisation de l'appareil MPS pour l'entraînement")
else:
    device = torch.device("cpu")
    print("Utilisation de l'appareil CPU pour l'entraînement")
# Out:
# Utilisation de l'appareil MPS pour l'entraînement

# %% [markdown]
# # Préparer le jeu de données CIFAR-10

# %%
import torchvision
import torchvision.transforms as transforms

# Prétraitement des données : conversion des images en tenseurs et normalisation de chaque canal dans l'intervalle [-1, 1]
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Télécharger et charger le jeu de données d'entraînement et de test CIFAR-10
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=16, shuffle=False, num_workers=2)

# Étiquettes de classification CIFAR-10
classes = ('avion', 'voiture', 'oiseau', 'chat', 'cerf', 'chien', 'grenouille', 'cheval', 'bateau', 'camion')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Définir le réseau de neurones convolutif (CNN)

# %%
import torch.nn as nn
import torch.nn.functional as F

# Définir un réseau de neurones convolutif
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)  # Première couche de convolution
        self.pool = nn.MaxPool2d(2, 2)   # Couche de pooling
        self.conv2 = nn.Conv2d(6, 16, 5) # Deuxième couche de convolution
        self.fc1 = nn.Linear(16 * 5 * 5, 120)  # Première couche entièrement connectée
        self.fc2 = nn.Linear(120, 84)          # Deuxième couche entièrement connectée
        self.fc3 = nn.Linear(84, 10)           # Dernière couche de sortie avec 10 classes (CIFAR-10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # Appliquer la première convolution suivie de ReLU et de pooling
        x = self.pool(F.relu(self.conv2(x)))  # Appliquer la deuxième convolution suivie de ReLU et de pooling
        x = x.view(-1, 16 * 5 * 5)            # Aplatir le tenseur pour les couches entièrement connectées
        x = F.relu(self.fc1(x))               # Appliquer la première couche entièrement connectée suivie de ReLU
        x = F.relu(self.fc2(x))               # Appliquer la deuxième couche entièrement connectée suivie de ReLU
        x = self.fc3(x)                       # Appliquer la couche de sortie
        return x

# Initialiser le modèle et le déplacer sur l'appareil (MPS ou CPU)
net = Net().to(device)

# %% [markdown]
# # Entraîner le modèle

# %%
import torch.optim as optim

# Définir la fonction de perte et l'optimiseur
criterion = nn.CrossEntropyLoss()  # Entropie croisée
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)  # Descente de gradient stochastique

# Entraîner le modèle
for epoch in range(30):  # 10 époques
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        # Déplacer les données vers l'appareil MPS
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()  # Réinitialiser les gradients

        outputs = net(inputs)  # Passer les données à travers le réseau
        loss = criterion(outputs, labels)  # Calculer la perte
        loss.backward()  # Backpropagation
        optimizer.step()  # Mise à jour des poids

        running_loss += loss.item()
        if i % 200 == 199:  # Afficher la perte toutes les 200 itérations
            print(f'Époque {epoch + 1}, Itération {i + 1} - Perte moyenne : {running_loss / 200:.4f}')
            running_loss = 0.0

# Fonction pour calculer la précision
def calculate_accuracy(loader, model):
    correct = 0
    total = 0
    with torch.no_grad():  # Désactiver la propagation des gradients
        for data in loader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return 100 * correct / total

# Afficher la précision après chaque époque
train_accuracy = calculate_accuracy(trainloader, net)
test_accuracy = calculate_accuracy(testloader, net)
print(f'Précision entraînement : {train_accuracy:.2f}%, Précision test : {test_accuracy:.2f}%')
print('Entraînement terminé')

# Sauvegarder le modèle
torch.save(net.state_dict(), 'cifar10_net_mps.pth')
# Out:
# Époque 1, Itération 200 - Perte moyenne : 2.2530
# Époque 1, Itération 400 - Perte moyenne : 1.9733
# Époque 1, Itération 600 - Perte moyenne : 1.7691
# Époque 1, Itération 800 - Perte moyenne : 1.6748
# Époque 1, Itération 1000 - Perte moyenne : 1.5946
# Époque 1, Itération 1200 - Perte moyenne : 1.5542
# Époque 1, Itération 1400 - Perte moyenne : 1.4923
# Époque 2, Itération 200 - Perte moyenne : 1.4653
# Époque 2, Itération 400 - Perte moyenne : 1.4265
# Époque 2, Itération 600 - Perte moyenne : 1.3958
# Époque 2, Itération 800 - Perte moyenne : 1.3513
# Époque 2, Itération 1000 - Perte moyenne : 1.3768
# Époque 2, Itération 1200 - Perte moyenne : 1.3451
# Époque 2, Itération 1400 - Perte moyenne : 1.3280
# Époque 3, Itération 200 - Perte moyenne : 1.2449
# Époque 3, Itération 400 - Perte moyenne : 1.2632
# Époque 3, Itération 600 - Perte moyenne : 1.2677
# Époque 3, Itération 800 - Perte moyenne : 1.2435
# Époque 3, Itération 1000 - Perte moyenne : 1.2344
# Époque 3, Itération 1200 - Perte moyenne : 1.2535
# Époque 3, Itération 1400 - Perte moyenne : 1.2329
# Époque 4, Itération 200 - Perte moyenne : 1.1609
# Époque 4, Itération 400 - Perte moyenne : 1.1801
# Époque 4, Itération 600 - Perte moyenne : 1.1933
# Époque 4, Itération 800 - Perte moyenne : 1.1553
# Époque 4, Itération 1000 - Perte moyenne : 1.1406
# Époque 4, Itération 1200 - Perte moyenne : 1.1466
# Époque 4, Itération 1400 - Perte moyenne : 1.1789
# Époque 5, Itération 200 - Perte moyenne : 1.0866
# Époque 5, Itération 400 - Perte moyenne : 1.1064
# Époque 5, Itération 600 - Perte moyenne : 1.1060
# Époque 5, Itération 800 - Perte moyenne : 1.1109
# Époque 5, Itération 1000 - Perte moyenne : 1.1067
# Époque 5, Itération 1200 - Perte moyenne : 1.1005
# Époque 5, Itération 1400 - Perte moyenne : 1.1172
# Époque 6, Itération 200 - Perte moyenne : 1.0143
# Époque 6, Itération 400 - Perte moyenne : 1.0133
# Époque 6, Itération 600 - Perte moyenne : 1.0563
# Époque 6, Itération 800 - Perte moyenne : 1.0604
# Époque 6, Itération 1000 - Perte moyenne : 1.0563
# Époque 6, Itération 1200 - Perte moyenne : 1.0734
# Époque 6, Itération 1400 - Perte moyenne : 1.0749
# Époque 7, Itération 200 - Perte moyenne : 0.9609
# Époque 7, Itération 400 - Perte moyenne : 0.9747
# Époque 7, Itération 600 - Perte moyenne : 1.0031
# Époque 7, Itération 800 - Perte moyenne : 1.0255
# Époque 7, Itération 1000 - Perte moyenne : 1.0207
# Époque 7, Itération 1200 - Perte moyenne : 1.0339
# Époque 7, Itération 1400 - Perte moyenne : 1.0074
# Époque 8, Itération 200 - Perte moyenne : 0.9221
# Époque 8, Itération 400 - Perte moyenne : 0.9457
# Époque 8, Itération 600 - Perte moyenne : 0.9521
# Époque 8, Itération 800 - Perte moyenne : 0.9836
# Époque 8, Itération 1000 - Perte moyenne : 0.9886
# Époque 8, Itération 1200 - Perte moyenne : 0.9721
# Époque 8, Itération 1400 - Perte moyenne : 0.9855
# Époque 9, Itération 200 - Perte moyenne : 0.8917
# Époque 9, Itération 400 - Perte moyenne : 0.9009
# Époque 9, Itération 600 - Perte moyenne : 0.9165
# Époque 9, Itération 800 - Perte moyenne : 0.9758
# Époque 9, Itération 1000 - Perte moyenne : 0.9322
# Époque 9, Itération 1200 - Perte moyenne : 0.9497
# Époque 9, Itération 1400 - Perte moyenne : 0.9750
# Époque 10, Itération 200 - Perte moyenne : 0.8701
# Époque 10, Itération 400 - Perte moyenne : 0.8906
# Époque 10, Itération 600 - Perte moyenne : 0.9014
# Époque 10, Itération 800 - Perte moyenne : 0.9146
# Époque 10, Itération 1000 - Perte moyenne : 0.9187
# Époque 10, Itération 1200 - Perte moyenne : 0.9002
# Époque 10, Itération 1400 - Perte moyenne : 0.9200
# Époque 11, Itération 200 - Perte moyenne : 0.8423
# Époque 11, Itération 400 - Perte moyenne : 0.8382
# Époque 11, Itération 600 - Perte moyenne : 0.8592
# Époque 11, Itération 800 - Perte moyenne : 0.8842
# Époque 11, Itération 1000 - Perte moyenne : 0.9165
# Époque 11, Itération 1200 - Perte moyenne : 0.9337
# Époque 11, Itération 1400 - Perte moyenne : 0.8921
# Époque 12, Itération 200 - Perte moyenne : 0.8008
# Époque 12, Itération 400 - Perte moyenne : 0.8207
# Époque 12, Itération 600 - Perte moyenne : 0.8565
# Époque 12, Itération 800 - Perte moyenne : 0.8368
# Époque 12, Itération 1000 - Perte moyenne : 0.8759
# Époque 12, Itération 1200 - Perte moyenne : 0.8685
# Époque 12, Itération 1400 - Perte moyenne : 0.8878
# Époque 13, Itération 200 - Perte moyenne : 0.7837
# Époque 13, Itération 400 - Perte moyenne : 0.8096
# Époque 13, Itération 600 - Perte moyenne : 0.8278
# Époque 13, Itération 800 - Perte moyenne : 0.8470
# Époque 13, Itération 1000 - Perte moyenne : 0.8643
# Époque 13, Itération 1200 - Perte moyenne : 0.8653
# Époque 13, Itération 1400 - Perte moyenne : 0.8867
# Époque 14, Itération 200 - Perte moyenne : 0.7655
# Époque 14, Itération 400 - Perte moyenne : 0.8053
# Époque 14, Itération 600 - Perte moyenne : 0.8047
# Époque 14, Itération 800 - Perte moyenne : 0.8493
# Époque 14, Itération 1000 - Perte moyenne : 0.8301
# Époque 14, Itération 1200 - Perte moyenne : 0.8439
# Époque 14, Itération 1400 - Perte moyenne : 0.9023
# Époque 15, Itération 200 - Perte moyenne : 0.7532
# Époque 15, Itération 400 - Perte moyenne : 0.7699
# Époque 15, Itération 600 - Perte moyenne : 0.7656
# Époque 15, Itération 800 - Perte moyenne : 0.8103
# Époque 15, Itération 1000 - Perte moyenne : 0.8299
# Époque 15, Itération 1200 - Perte moyenne : 0.8422
# Époque 15, Itération 1400 - Perte moyenne : 0.8504
# Époque 16, Itération 200 - Perte moyenne : 0.7299
# Époque 16, Itération 400 - Perte moyenne : 0.7674
# Époque 16, Itération 600 - Perte moyenne : 0.7824
# Époque 16, Itération 800 - Perte moyenne : 0.7854
# Époque 16, Itération 1000 - Perte moyenne : 0.8160
# Époque 16, Itération 1200 - Perte moyenne : 0.8346
# Époque 16, Itération 1400 - Perte moyenne : 0.8504
# Époque 17, Itération 200 - Perte moyenne : 0.7239
# Époque 17, Itération 400 - Perte moyenne : 0.7273
# Époque 17, Itération 600 - Perte moyenne : 0.7871
# Époque 17, Itération 800 - Perte moyenne : 0.7871
# Époque 17, Itération 1000 - Perte moyenne : 0.8144
# Époque 17, Itération 1200 - Perte moyenne : 0.8365
# Époque 17, Itération 1400 - Perte moyenne : 0.8148
# Époque 18, Itération 200 - Perte moyenne : 0.6882
# Époque 18, Itération 400 - Perte moyenne : 0.7323
# Époque 18, Itération 600 - Perte moyenne : 0.7865
# Époque 18, Itération 800 - Perte moyenne : 0.7596
# Époque 18, Itération 1000 - Perte moyenne : 0.8054
# Époque 18, Itération 1200 - Perte moyenne : 0.8031
# Époque 18, Itération 1400 - Perte moyenne : 0.8242
# Époque 19, Itération 200 - Perte moyenne : 0.6960
# Époque 19, Itération 400 - Perte moyenne : 0.7670
# Époque 19, Itération 600 - Perte moyenne : 0.7714
# Époque 19, Itération 800 - Perte moyenne : 0.7671
# Époque 19, Itération 1000 - Perte moyenne : 0.7900
# Époque 19, Itération 1200 - Perte moyenne : 0.7817
# Époque 19, Itération 1400 - Perte moyenne : 0.8039
# Époque 20, Itération 200 - Perte moyenne : 0.6557
# Époque 20, Itération 400 - Perte moyenne : 0.7226
# Époque 20, Itération 600 - Perte moyenne : 0.7241
# Époque 20, Itération 800 - Perte moyenne : 0.7418
# Époque 20, Itération 1000 - Perte moyenne : 0.8000
# Époque 20, Itération 1200 - Perte moyenne : 0.7899
# Époque 20, Itération 1400 - Perte moyenne : 0.8124
# Époque 21, Itération 200 - Perte moyenne : 0.6918
# Époque 21, Itération 400 - Perte moyenne : 0.6953
# Époque 21, Itération 600 - Perte moyenne : 0.7253
# Époque 21, Itération 800 - Perte moyenne : 0.7549
# Époque 21, Itération 1000 - Perte moyenne : 0.7696
# Époque 21, Itération 1200 - Perte moyenne : 0.7990
# Époque 21, Itération 1400 - Perte moyenne : 0.8032
# Époque 22, Itération 200 - Perte moyenne : 0.6828
# Époque 22, Itération 400 - Perte moyenne : 0.7265
# Époque 22, Itération 600 - Perte moyenne : 0.7126
# Époque 22, Itération 800 - Perte moyenne : 0.7722
# Époque 22, Itération 1000 - Perte moyenne : 0.7409
# Époque 22, Itération 1200 - Perte moyenne : 0.7774
# Époque 22, Itération 1400 - Perte moyenne : 0.7902
# Époque 23, Itération 200 - Perte moyenne : 0.6570
# Époque 23, Itération 400 - Perte moyenne : 0.7000
# Époque 23, Itération 600 - Perte moyenne : 0.7359
# Époque 23, Itération 800 - Perte moyenne : 0.7741
# Époque 23, Itération 1000 - Perte moyenne : 0.7471
# Époque 23, Itération 1200 - Perte moyenne : 0.7581
# Époque 23, Itération 1400 - Perte moyenne : 0.7972
# Époque 24, Itération 200 - Perte moyenne : 0.6852
# Époque 24, Itération 400 - Perte moyenne : 0.7008
# Époque 24, Itération 600 - Perte moyenne : 0.7328
# Époque 24, Itération 800 - Perte moyenne : 0.7240
# Époque 24, Itération 1000 - Perte moyenne : 0.7618
# Époque 24, Itération 1200 - Perte moyenne : 0.7333
# Époque 24, Itération 1400 - Perte moyenne : 0.7562
# Époque 25, Itération 200 - Perte moyenne : 0.6985
# Époque 25, Itération 400 - Perte moyenne : 0.7034
# Époque 25, Itération 600 - Perte moyenne : 0.7265
# Époque 25, Itération 800 - Perte moyenne : 0.7584
# Époque 25, Itération 1000 - Perte moyenne : 0.7585
# Époque 25, Itération 1200 - Perte moyenne : 0.7835
# Époque 25, Itération 1400 - Perte moyenne : 0.7556
# Époque 26, Itération 200 - Perte moyenne : 0.6602
# Époque 26, Itération 400 - Perte moyenne : 0.6733
# Époque 26, Itération 600 - Perte moyenne : 0.7356
# Époque 26, Itération 800 - Perte moyenne : 0.7374
# Époque 26, Itération 1000 - Perte moyenne : 0.7365
# Époque 26, Itération 1200 - Perte moyenne : 0.7685
# Époque 26, Itération 1400 - Perte moyenne : 0.7525
# Époque 27, Itération 200 - Perte moyenne : 0.6485
# Époque 27, Itération 400 - Perte moyenne : 0.6684
# Époque 27, Itération 600 - Perte moyenne : 0.6888
# Époque 27, Itération 800 - Perte moyenne : 0.7167
# Époque 27, Itération 1000 - Perte moyenne : 0.7359
# Époque 27, Itération 1200 - Perte moyenne : 0.7228
# Époque 27, Itération 1400 - Perte moyenne : 0.7618
# Époque 28, Itération 200 - Perte moyenne : 0.6664
# Époque 28, Itération 400 - Perte moyenne : 0.6860
# Époque 28, Itération 600 - Perte moyenne : 0.7356
# Époque 28, Itération 800 - Perte moyenne : 0.7178
# Époque 28, Itération 1000 - Perte moyenne : 0.7432
# Époque 28, Itération 1200 - Perte moyenne : 0.7383
# Époque 28, Itération 1400 - Perte moyenne : 0.7767
# Époque 29, Itération 200 - Perte moyenne : 0.6748
# Époque 29, Itération 400 - Perte moyenne : 0.6898
# Époque 29, Itération 600 - Perte moyenne : 0.7193
# Époque 29, Itération 800 - Perte moyenne : 0.6943
# Époque 29, Itération 1000 - Perte moyenne : 0.7313
# Époque 29, Itération 1200 - Perte moyenne : 0.7602
# Époque 29, Itération 1400 - Perte moyenne : 0.7879
# Époque 30, Itération 200 - Perte moyenne : 0.6402
# Époque 30, Itération 400 - Perte moyenne : 0.7010
# Époque 30, Itération 600 - Perte moyenne : 0.6870
# Époque 30, Itération 800 - Perte moyenne : 0.7256
# Époque 30, Itération 1000 - Perte moyenne : 0.7752
# Époque 30, Itération 1200 - Perte moyenne : 0.7377
# Époque 30, Itération 1400 - Perte moyenne : 0.7569
# Précision entraînement : 76.25%, Précision test : 59.03%
# Entraînement terminé

# %% [markdown]
# # Évaluer le modèle

# %%
correct = 0
total = 0

# Désactiver la propagation en arrière pour l'évaluation
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)  # Prendre l'indice avec la probabilité la plus élevée
        total += labels.size(0)  # Compter le nombre total d'images
        correct += (predicted == labels).sum().item()  # Compter les prédictions correctes

print(f'Précision du réseau sur les 10000 images de test : {100 * correct / total}%')
# Out:
# Précision du réseau sur les 10000 images de test : 59.03%

# %% [markdown]
# # Modèle de CoreML

# %%
example_input = torch.rand(1, 3, 32, 32).to(device)
traced_model = torch.jit.trace(net, example_input)

# %%
import coremltools as ct

net.eval()

coreml_model = ct.convert(
    traced_model,
    inputs=[ct.ImageType(name="image", shape=(1, 3, 32, 32), scale=1/127.5, bias=[-1, -1, -1])],
    classifier_config=ct.ClassifierConfig(class_labels=list(classes))
    )

coreml_model.save("CIFAR10NetMPS_4.mlpackage")
# Out:
# When both 'convert_to' and 'minimum_deployment_target' not specified, 'convert_to' is set to "mlprogram" and 'minimum_deployment_target' is set to ct.target.iOS15 (which is same as ct.target.macOS12). Note: the model will not run on systems older than iOS15/macOS12/watchOS8/tvOS15. In order to make your model run on older system, please set the 'minimum_deployment_target' to iOS14/iOS13. Details please see the link: https://apple.github.io/coremltools/docs-guides/source/target-conversion-formats.html
# Model is not in eval mode. Consider calling '.eval()' on your model prior to conversion
# Converting PyTorch Frontend ==> MIL Ops:  98%|█████████▊| 46/47 [00:00<00:00, 9448.94 ops/s]
# Running MIL frontend_pytorch pipeline: 100%|██████████| 5/5 [00:00<00:00, 2978.06 passes/s]
# Running MIL default pipeline: 100%|██████████| 78/78 [00:00<00:00, 1642.55 passes/s]
# Running MIL backend_mlprogram pipeline: 100%|██████████| 12/12 [00:00<00:00, 2642.64 passes/s]
